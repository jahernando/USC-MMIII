# %% [markdown]
# ### Folla 1 - Conjuntos de nivel
#
# February 2020

# %%
import time
print(' Last version ', time.asctime() )
# Out:
#  Last version  Tue Feb 15 09:57:05 2022

# %%
import os
import sys
mypath = os.getcwd()
mypath = '/Users/hernando/docencia/grado/Metodos-III/USC-MMIII/'
sys.path.insert(0, os.path.abspath(mypath))

# %%
# general imports
# %matplotlib notebook
# %load_ext autoreload
# %autoreload 2

# numpy and matplotlib
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
plt.style.context('seaborn-colorblind')
#matplotlib.style.use('ggplot')
import graph_utils as gf

# %% [markdown]
# ### ejercicio 1.
#
# 1.1 $f(x, y) = x + y$
#
# 1.2 $f(x, y) = x^2 - y^2$
#
# 1.3 $f(x, y) = (x + y)^2$
#
# 1.4 $f(x, y) = x y$
#
# 1.5 $f(x, y) $
#
# 1.6 $\max(|x|, |y|)$
#
# 1.7 $x^y$ con $x >0$
#
# 1.8 $\frac{y}{x^2 + y^2}$
#
# 1.9 $\sqrt{1/y - x^2}$
#
# 1.10 $\cos(x + y)$
#
# 1.11 $\frac{-1}{\sqrt{x^2 + y^2}}$
#
# 1.12 $\frac{x^2}{16} + y^2$

# %% [markdown]
# 1.1 $f(x, y) = x + y$
#
# $x + y = c, \;\; y = - x + c$
#
# Son rectas con pendiente $-1$ y umbral en el origen $c$

# %%
fun = lambda x, y : x + y
xrange, yrange = (-5., 5., 100), (-5., 5., 100)
gf.graph  (fun, xrange, yrange);
gf.contour(fun, xrange, yrange);
# Out:
# <img src="data:image/png;base64,..." width="630.8">
# <img src="data:image/png;base64,..." width="630.8">

# %% [markdown]
# 1.2 $f(x, y) = x^ - y^2$
#
# $x^2 - y^2 = c, \;\; y^2 = x^2 - c $,
#
# Son hipérbolas. En el caso $c = 0$, son las rectas $y = \pm x$

# %%
fun = lambda x, y : x*x - y*y
xrange, yrange = (-5., 5., 100), (-5., 5., 100)
gf.graph  (fun, xrange, yrange);
gf.contour(fun, xrange, yrange);

# %% [markdown]
# 1.3 $f(x, y) = (x + y)^2$
#
# $(x + y)^2 = c, \;\; y = \sqrt{c} - x $,
#
# Son rectas, con pendiente -1 y umbral $\sqrt{c}$

# %%
fun = lambda x, y : (x + y)**2
xrange, yrange = (-5., 5., 100), (-5., 5., 100)
gf.graph  (fun, xrange, yrange);
gf.contour(fun, xrange, yrange);

# %% [markdown]
# 1.4 $f(x, y) = x \, y$
#
# $x \, y  = c, \;\; y = c / x $,
#
# Son curvas con $1/x$. Cuando $c = 0$ los ejes son los conuntos de nivel

# %%
fun = lambda x, y : x*y
xrange, yrange = (-5., 5., 100), (-5., 5., 100)
gf.graph  (fun, xrange, yrange);
gf.contour(fun, xrange, yrange);

# %% [markdown]
# 1.5 $f(x, y) = x / y$
#
# $x / y  = c, \;\; y = x / c $,
#
# Son rectas con pendiente $1/c$ que pasan por el origen. El eje $y$ no está definido en el dominio.

# %%
fun = lambda x, y : x/y # tan(phi)
xrange, yrange = (-1., 1., 100), (-1., 1., 100)
gf.graph  (fun, xrange, yrange);
gf.contour(fun, xrange, yrange);

# %% [markdown]
# ### 1.6
#
# $f(x, y) = \max(|x|, |y|)$
#
# Los conjuntos de nivel son cuadrados centrados en el origen con vértices en (c, c), (-c, c), (-c, -c), (c, -c)

# %%
def fun(x, y):
    return np.maximum(np.abs(x), np.abs(y))

xrange, yrange = (-10., 10., 100), (-10., 10., 100)
#gf.graph   (fun, xrange, yrange);

xs = np.linspace(-10., 10., 100)
ys = np.linspace(-10., 10., 100)
xms, yms = np.meshgrid(xs, ys)
zms = fun(xms, yms)

ax = plt.gca(projection='3d')
ax.plot_surface(xms, yms, zms);
plt.figure()
plt.contour(xs, ys, zms);
plt.gca().set_aspect('equal');
#plt.aspect('equal')
# Out:
# <img src="data:image/png;base64,..." width="505.4">

# %% [markdown]
# ### 1.7
#
# $f(x, y) = x^y$, con $x >0.$
#
#
# $x^y = c, \; y \, \log (x) = \log c, \; y = \frac{log(c)}{\log(x)}$, con $c >0$

# %%
fun = lambda x, y : x**y
xrange, yrange = (1e-6, 2., 100), (0., 2., 101)
gf.graph  (fun, xrange, yrange);
gf.contour(fun, xrange, yrange);

# %% [markdown]
# ### 1.8
#
# $f(x, y) = \frac{y}{x^2 + y^2}$
#
#
# $y/c = x^2 + y^2, \; y^2 - y/c + x^2 = 0, \; (y - \frac{1}{2c})^2 + x^2 = \frac{1}{4c^2}$

# %%
fun = lambda x, y : y / (x*x + y*y) # sin(phi)/r
xrange, yrange = (-0.5, 0.5, 100), (-0.5, 0.5, 100)
gf.graph  (fun, xrange, yrange);
gf.contour(fun, xrange, yrange);

# %% [markdown]
# ### 1.9
#
# $f(x,y) = \sqrt{\frac{1}{y} - x^2}$
#
# Se tiene que cumplir que $\frac{1}{y} - x^2 \ge 0$, esto obliga a  $y \le \frac{1}{x^2}$ e $y > 0$
#
# $f(x,y) = \sqrt{\frac{1}{y} - x^2} = c, \;\; \frac{1}{y} - x^2 = c^2$
#
# $y = \frac{1}{c^2+x^2}$

# %%
def fun(x, y):
    val = np.maximum(1/y - x*x, 0.)
    val = np.sqrt(val)
    return val
xrange, yrange = (-5., 5., 100), (0.1, 5., 100)
gf.graph  (fun, xrange, yrange);
gf.contour(fun, xrange, yrange);

# %% [markdown]
# ### 1.10
#
# $f(x, y) = \cos (x + y)$
#
#
# $x + y = \arccos(c) + 2 n \pi, \; y = -x + \arccos(c) + 2 n \pi$, con $n = \pm1, \pm2, \dots$

# %%
fun = lambda x, y : np.cos(x + y)
xrange, yrange = (-2.*np.pi, 2.*np.pi, 100), (-2.*np.pi, 2.*np.pi, 100)
gf.graph  (fun, xrange, yrange);
gf.contour(fun, xrange, yrange);
# Out:
# <img src="data:image/png;base64,..." width="630.8">
# <img src="data:image/png;base64,..." width="630.8">

# %% [markdown]
# ### 1.11
#
# $f(x, y) = \frac{-1}{\sqrt{x^2 + y^2}}$
#
#
# $\frac{1}{c^2} = x^2 + y^2$, circunferencias de radio $1/c$

# %%
fun = lambda x, y : -1/ np.sqrt(x*x + y*y)
xrange, yrange = (-np.pi, np.pi, 100), (-np.pi, np.pi, 100)
gf.graph  (fun, xrange, yrange);
gf.contour(fun, xrange, yrange);

# %% [markdown]
# ### 1.12
#
# $f(x, y) = \frac{x^2}{16} + y^2$
#
# $\frac{x^2}{16} + y^2 = c$, con $c > 0$, son elipses.

# %%
fun = lambda x, y : x*x/16. + y*y
xrange, yrange = (-np.pi, np.pi, 100), (-np.pi, np.pi, 100)
gf.graph  (fun, xrange, yrange);
gf.contour(fun, xrange, yrange);

# %% [markdown]
# ## ejercicio 2
#
# Dibuja los conjuntos de nivel para $$c = 0, 1
#
# 2.1 $f(x, y, z) = 3x$
#
# 2.2 $f(x, y, z) = x + y + z$
#
# 2.3 $f(x, y, z) = x^2 + y^2 + z^2$
#
# 2.4 $f(x, y, z) = x^2 + y^2 - z^2$
#
# 2.5 $f(x, y, z) = x^2 + 4y^2 + 3z^2$
#
# 2.6 $f(x, y, z) = \frac{1}{x^2 + z^2}$

# %% [markdown]
# ### 2.1
#
# $f(x, y, z) = 3x$
#
# * c = 0, c= 1, se trata del plano (y, z) con x = 0 o x = 1/3

# %% [markdown]
# ### 2.2
#
# $f(x, y, z) = x + y + z$
#
# * c = 0, 1, se trata de planos con $z = -x - y + c$, con pendientes -1 en $x$ e $y$ y que pasan por el origen en $(0, 0, c$.

# %%
c = 0.
z = lambda x, y : -x - y - c
xrange, yrange = (-1., 1., 100), (-1., 1., 100)
gf.graph  (z, xrange, yrange);
gf.contour(z, xrange, yrange);

# %% [markdown]
# ### 2.3
#
# $f(x, y, z) = x^2 + y^2 + z^2 = c$
#
#   * $c = 0$, un solo punto, el origen, $(0, 0, 0)$
#
#   * $c = 1$, una esfera de radio unidad

# %%
c = 0.5
r = np.sqrt(c)
rs   = np.linspace(0, r, 100)
phis = np.linspace(0, 2 * np.pi, 100)
rms, phims = np.meshgrid(rs, phis)
xms   = rms * np.cos(phims)
yms   = rms * np.sin(phims)
zms   = np.sqrt(r * r - rms * rms )
ax    = plt.gca(projection='3d')
ax.plot_wireframe(xms, yms,  zms, alpha = 0.5, color = 'b')
ax.plot_wireframe(xms, yms, -zms, alpha = 0.5, color = 'b')
#ax.set_aspect('equal');

# %% [markdown]
# ### 2.4
#
# $f(x, y, z) = x^2 + y^2 - z^2 = c$
#
#   * $c = 0$, se trata de un cónica, $z = \sqrt{x^2 + y^2}$, con conexión en el origen
#
#   * $c = 1$, se trata de un paraboliode, con conexión en el $z=0$ con una circunferencia de radio unidad.
#   $z^2 = x^2 + y^2 - c$, caso $z = 0, \;\; x^2 + y^2 = c$
#
#   * $c = -1$, se trata de un paraboloide con dos hojas desconectadas, la superior y la inferior.
#   $x^2 + y^2 = z^2 - |c|$, para $|c| = 1, c = -1$, tendríamos dos puntos $(0, 0, \pm 1)$. Y en $z = \pm 2$, dos circunferencias en $(x, y)$ de radio unidad.

# %%
c = 1.
r = np.sqrt(c)
rs   = np.linspace(r, 2*r, 100)
phis = np.linspace(0, 2 * np.pi, 100)
rms, phims = np.meshgrid(rs, phis)
xms   = rms * np.cos(phims)
yms   = rms * np.sin(phims)
zms   = np.sqrt(- r * r + rms * rms )
ax    = plt.gca(projection='3d')
ax.plot_wireframe(xms, yms,  zms, alpha = 0.5, color = 'b')
ax.plot_wireframe(xms, yms, -zms, alpha = 0.5, color = 'b')
#ax.set_aspect('equal');

# %% [markdown]
# ### 2.5
#
# $f(x, y, z) = x^2 + 4 y^2 + 3z^2$
#
# se trata de un elipsoide
#
#  * c = 0, de un solo punto (0, 0, 0)
#
#  * c = 1, es un elipsoide, $x^2 + 4 y^2 + 3z^2 = 1$
#
#  Notar que si cambiamos las bariables $y' = 2 y, \; z' = \sqrt{3} z$, queda: $x^2 + y'^2 + z'^2 = 1$, una esfera de radio unidad. Luego se trata de coger una esfera y de achatar en este caso sus ejes: $y = y'/2, \; z = z'/\sqrt{3}$.

# %%
cc = 2.
a, b, c = np.sqrt(cc), np.sqrt(cc/4.), np.sqrt(cc/3.)
a, b, c = 1., 1., 0.1
rs   = np.linspace(0, 1., 40)
phis = np.linspace(0, 2 * np.pi, 40)
rms, phims = np.meshgrid(rs, phis)
xms   = rms * np.cos(phims)/a
yms   = rms * np.sin(phims)/b
zms   = np.sqrt(1 - rms * rms)/c
ax    = plt.gca(projection='3d')
ax.plot_wireframe(xms, yms,  zms, alpha = 0.5, color = 'b')
ax.plot_wireframe(xms, yms, -zms, alpha = 0.5, color = 'b')

# %% [markdown]
# ### 2.6
#
# $f(x, y, z) = \frac{1}{x^2 + z^2}$
#
# * caso c = 0, $x^2 + z^2 \to \infty$, cualquier y
#
# * caso c = 1, $x^2 + z^2 = 1$ cualquier $y$, un cilindro de base una circunferencia, centrado en el origen, de radio unidad y eje $y$.

# %% [markdown]
# ## Ejercicio 3
#
# 3.1 Indica los conjuntos de nivel para $f(x, y) = x^2 - 2x + y^2$ con $c = -1, 0, 1$
#
# 3.2 Indica los conjuntos de nivel para $f(x, y) = \sin(y^2 + x^2 - 2xy)$ para $c = -1, 0, 1$

# %% [markdown]
# ### 3.1
#
# Simplificamos la función: $x^2 - 2x + y^2 = (x-1)^2 + y^2 - 1$
#
# $(x-1)^2 + y^2 - 1 = c; \;\; (x-1)^2 + y^2 = 1 + c$
#
# * c = -1, es un punto (1, 0)
#
# * c = 0, es la circunferencia de radio 1 centradad en el punto (1, 0)
#
# * c = 1, es una circunferencia de radio $\sqrt{2}$ centrada en el punto (1, 0)

# %% [markdown]
# ### 3.2
#
#
# Los conjuntos de nivel son los mimos que para $y^2 + x^2 - 2xy = (y - x)^2$
#
#  * c = -1, no puede ser porque $(y-x)^2$ es positivo siempre.
#
#  * c = 0, una recta, $y = x$
#
#  * c = 1, las rectas $y = x \pm 1$

# %% [markdown]
# ## Ejercicio 4
#
# De acuerdo con la figura, indica qué punto es más costero, A, B
#
# Describe la topografía en torno a C

# %% [markdown]
# i ) Es más costero A porque las curvas de nivel están más próximas entre sí.
#
# ii) El punto C es un punto silla, en una dirección bajamos y en la otra subimos.
